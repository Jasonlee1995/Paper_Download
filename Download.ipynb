# %% [markdown]
# # 1. Import Python Files
#
# - Import files that you want to download

# %%
import _ICLR

# %% [markdown]
# # 2. Define Years to Download
#
# - Define years to download as list format

# %%
years = [2014, 2015, 2016, 2018, 2019]

# %% [markdown]
# # 3. Download Papers on *paper* Folder

# %%
for year in years:
    _ICLR.download(year)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 35/35 [01:32<00:00,  5.45s/it]
# 35it [01:32,  2.63s/it]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 103/103 [03:33<00:00,  7.88s/it]
# 103it [03:33,  2.08s/it]
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 80/80 [03:17<00:00,  4.50s/it]
# 80it [03:17,  2.47s/it]
# ...
#  62%|█████████████████████████████████████████████████▊                              | 209/336 [02:20<01:17,  1.64it/s]
# ...
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 501/501 [06:52<00:00,  1.21s/it]
# 501it [06:52,  1.21it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 501/501 [06:52<00:00,  1.21it/s]
